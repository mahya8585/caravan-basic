# %%
1+1
# Out:
# 2

# %% [markdown]
# あいうえお

# %% [markdown]
# #### はじめに

# %% [markdown]
# # はじめに

# %%
2*3
# Out:
# 6

# %%
10%3
# Out:
# 1

# %%
'Hokkaido'
# Out:
# 'Hokkaido'

# %%
'ドン' * 4 +'キー'
# Out:
# 'ドンドンドンドンキー'

# %%
don = 'ドン'
key = 'キー'

# %%
don * 4 + key + don + key + 'ホーテ～'
# Out:
# 'ドンドンドンドンキードンキーホーテ～'

# %%
foods = ['寿司', 'スープカレー', '味噌ラーメン']

# %%
foods
# Out:
# ['寿司', 'スープカレー', '味噌ラーメン']

# %%
foods[0]
# Out:
# 'スープカレー'

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 10.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.5 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 18.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data.csv')

# %%
df
# Out:
#     No   地方    chihou 都道府県  area_km2  population_k  female_k  ramen_shop  \
# 0    1  北海道  Hokkaido  北海道     83424          5320      2814        1898
# 1    2   東北    Tohoku   青森      9646          1278       678         482
# 2    3   東北    Tohoku   岩手     15275          1255       651         363
# 3    4   東北    Tohoku   宮城      6859          2323      1188         726
# 4    5   東北    Tohoku   秋田     11638           996       528         390
# 5    6   東北    Tohoku   山形      6652          1102       571         732
# 6    7   東北    Tohoku   福島     13784          1882       951         731
# 7    8   関東     Kanto   茨城      6097          2892      1450         867
# 8    9   関東     Kanto   栃木      6408          1957       983         896
# 9   10   関東     Kanto   群馬      6362          1960       992         660
# 10  11   関東     Kanto   埼玉      3768          7310      3662        1145
# 11  12   関東     Kanto   千葉      5083          6246      3143        1298
# ...

# %%
df.tail()
# Out:
#     No  地方   chihou 都道府県  area_km2  population_k  female_k  ramen_shop  \
# 42  43  九州  Kyushyu   熊本      7272          1765       933         546
# 43  44  九州  Kyushyu   大分      5100          1152       607         287
# 44  45  九州  Kyushyu   宮崎      6794          1089       577         356
# 45  46  九州  Kyushyu  鹿児島      9043          1626       863         567
# 46  47  九州  Kyushyu   沖縄      2281          1443       734         232
#
#       sake_l  sake_l_person  mcdnald_shop  yakitori_shop  name_sato  \
# 42   9375000           6.47            34            327      12400
# 43   7330000           7.64            24            229      39500
# 44   8362000           9.34            17            229      13600
# 45  12630000           9.43            24            234       3100
# 46   9694000           8.75            41            136        800
#
#     name_kato  online_game  source_ml  moyashi_g  mikan_g  orange_g
# ...

# %%
df.shape
# Out:
# (47, 19)

# %%
df.describe()
# Out:
#               No      area_km2  population_k     female_k   ramen_shop  \
# count  47.000000     47.000000     47.000000    47.000000    47.000000
# mean   24.000000   7770.021277   2695.914894  1384.148936   651.042553
# std    13.711309  11704.121820   2754.775654  1396.677486   560.493221
# min     1.000000   1863.000000    565.000000   295.000000   155.000000
# 25%    12.500000   4139.500000   1095.500000   574.000000   269.500000
# 50%    24.000000   5759.000000   1626.000000   863.000000   456.000000
# 75%    35.500000   7262.500000   2714.000000  1403.500000   846.500000
# max    47.000000  83424.000000  13724.000000  6964.000000  3139.000000
#
#              sake_l  sake_l_person  mcdnald_shop  yakitori_shop  \
# count  4.700000e+01      47.000000     47.000000       47.00000
# mean   1.535209e+07       6.763404     61.361702      326.06383
# std    1.823206e+07       1.115264     70.972262      399.80405
# min    3.221000e+06       4.940000      8.000000       52.00000
# ...

# %%
df.sort_values(by=['ramen_shop'], ascending=False).head()
# Out:
#     No   地方    chihou 都道府県  area_km2  population_k  female_k  ramen_shop  \
# 12  13   関東     Kanto   東京      2106         13724      6964        3139
# 0    1  北海道  Hokkaido  北海道     83424          5320      2814        1898
# 13  14   関東     Kanto  神奈川      2416          9159      4590        1439
# 39  40   九州   Kyushyu   福岡      4854          5107      2692        1436
# 22  23   中部     Chubu   愛知      5123          7525      3761        1423
#
#        sake_l  sake_l_person  mcdnald_shop  yakitori_shop  name_sato  \
# 12  110043000           9.54           346           2134     213000
# 0    33810000           7.49            87            669     161000
# 13   46518000           6.14           221            865     164000
# 39   29078000           6.95            97           1412      33800
# 22   33363000           5.46           193            707      72400
#
#     name_kato  online_game  source_ml  moyashi_g  mikan_g  orange_g
# ...

# %%
df['area_shop'] = df['area_km2'] / df['ramen_shop']
df.sort_values(by=['area_shop'], ascending=False).head()
# Out:
#     No   地方    chihou 都道府県  area_km2  population_k  female_k  ramen_shop  \
# 0    1  北海道  Hokkaido  北海道     83424          5320      2814        1898
# 38  39   四国   Shikoku   高知      7104           714       377         168
# 2    3   東北    Tohoku   岩手     15275          1255       651         363
# 31  32   中国   Chugoku   島根      6708           685       355         201
# 4    5   東北    Tohoku   秋田     11638           996       528         390
#
#       sake_l  sake_l_person  mcdnald_shop  yakitori_shop  name_sato  \
# 0   33810000           7.49            87            669     161000
# 38   4501000           7.44            11             76        980
# 2    8199000           7.72            14             89      65200
# 31   3986000           6.97             8             52       5300
# 4    7114000           8.24            15             59      81900
#
#     name_kato  online_game  source_ml  moyashi_g  mikan_g  orange_g  area_shop
# ...

# %%
df.groupby('地方')['ramen_shop'].describe()
# Out:
#      count         mean         std     min      25%     50%      75%     max
# 地方
# 中国     5.0   387.000000  271.109756   155.0   201.00   297.0   456.00   826.0
# 中部     9.0   641.111111  404.022414   210.0   385.00   442.0   935.00  1423.0
# 九州     8.0   493.125000  402.720193   232.0   266.75   321.5   551.25  1436.0
# 北海道    1.0  1898.000000         NaN  1898.0  1898.00  1898.0  1898.00  1898.0
# 四国     4.0   227.750000   65.168372   168.0   178.50   217.5   266.75   308.0
# 東北     6.0   570.666667  178.600859   363.0   413.00   604.0   729.75   732.0
# 近畿     7.0   467.428571  380.394031   167.0   195.00   316.0   599.00  1201.0
# 関東     7.0  1349.142857  833.533728   660.0   881.50  1145.0  1368.50  3139.0

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'MS Gothic'

# plt.rcParams['font.family'] = 'Hiragino Sans'

# %%
plt.bar(df['地方'], df['area_km2'], color='pink')
# Out:
# <BarContainer object of 47 artists>

# %%
plt.scatter(df['online_game'], df['population_k'])

# %%
df.sort_values(by=['online_game'], ascending=False)
